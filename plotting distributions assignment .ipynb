# %%
import matplotlib.pyplot as mat

# %%
import pandas as pd

# %%
import seaborn as sea

# %% [markdown]
# ## ABOUT THE DATASET

# %% [markdown]
# #### This data set is gathered from Instagram users who were chosen randomly.
# #### The Main data set encompasses data for 1K users including 500 men and 500 women. The Test data set encompasses data for 100 users including 50 men and 50 women.

# %%
insta=pd.read_csv("C:/Users/anand/OneDrive/Desktop/instagram.csv")

# %%
insta
# Out:
#          Users  Number of Posts  Number_of_Followers  Number_of_Followings  \
# 0       User-1              486                  279                    19
# 1       User-2              401                 5509                   342
# 2       User-3              463                  453                   293
# 3       User-4              154                 1231                  1477
# 4       User-5              786                 9620                   421
# ..         ...              ...                  ...                   ...
# 995   User-996             2599                 2684                  7300
# 996   User-997             2284                 4020                  2978
# 997   User-998              164                 2326                  6920
# 998   User-999               89                  286                   715
# 999  User-1000               83                 1587                  4997
#
#      Number of Likes for the Tenth Previous Post  \
# ...

# %%
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Users                                                     1000 non-null   object
#  1   Number of Posts                                           1000 non-null   int64
#  2   Number_of_Followers                                       1000 non-null   int64
#  3   Number_of_Followings                                      1000 non-null   int64
#  4   Number of Likes for the Tenth Previous Post               1000 non-null   int64
#  5   Number of Likes for the Eleventh Previous Post            1000 non-null   int64
#  6   Number of Likes for the Twelfth Previous Post             1000 non-null   int64
#  7   Number of Self-Presenting Posts from Nine Previous Posts  1000 non-null   int64
# ...

# %%
insta['Number of Posts']=insta['Number of Posts'].astype('int64')
insta['Number_of_Followers']=insta['Number_of_Followers'].astype('int64')
insta['Number_of_Followings']=insta['Number_of_Followings'].astype('int64')

# %%
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Users                                                     1000 non-null   object
#  1   Number of Posts                                           1000 non-null   int64
#  2   Number_of_Followers                                       1000 non-null   int64
#  3   Number_of_Followings                                      1000 non-null   int64
#  4   Number of Likes for the Tenth Previous Post               1000 non-null   int64
#  5   Number of Likes for the Eleventh Previous Post            1000 non-null   int64
#  6   Number of Likes for the Twelfth Previous Post             1000 non-null   int64
#  7   Number of Self-Presenting Posts from Nine Previous Posts  1000 non-null   int64
# ...

# %%
insta.describe()
# Out:
#        Number of Posts  Number_of_Followers  Number_of_Followings  \
# count      1000.000000           1000.00000           1000.000000
# mean        425.202000           1542.06100           1979.402000
# std         671.586881           1978.69823           2013.881415
# min          33.000000             16.00000             11.000000
# 25%         101.000000            357.00000            500.750000
# 50%         203.000000            769.00000           1112.500000
# 75%         459.500000           1710.25000           2778.000000
# max        7733.000000           9953.00000           7735.000000
#
#        Number of Likes for the Tenth Previous Post  \
# count                                  1000.000000
# mean                                    114.621000
# std                                     197.677054
# min                                       0.000000
# 25%                                      20.000000
# 50%                                      47.500000
# ...

# %% [markdown]
# #### In this dataset ,it shows us the basic statistical data of dataset,Like Count, Mean, STD, min, 25th percentile, 50th percentile, 75th percentile and max functions.

# %%
mat.boxplot(insta['Number of Likes for the Eleventh Previous Post'])
mat.show()

# %% [markdown]
# #### We have taken boxplot for ''Number of Likes for the Eleventh Previous Post'' variable in the dataset, where there are outliers in the 2000and 1600, It displays us the boxplot is plotted b/w the value 50 to 250.

# %%
mat.boxplot(insta['Number_of_Followers'])
mat.yscale('log')
mat.show()

# %% [markdown]
# #### In this dataset, We have taken log scale in order to display the boxplot, where it gives clear view to understand about dataset in a better way.

# %%
mat.hist(insta['Number of Posts'],color='g')
mat.show()

# %% [markdown]
# ##### We have displayed a histogram for the variable,'Number of Posts' it displays us that the histogram reaches its peak in 1 to 900values ,where the peak value is 900 and there are no values after 3100 to 8000 and above.

# %%
mat.hist(insta['Number of Posts'])
mat.yscale('log')
mat.show()

# %% [markdown]
# #### By taking the log scale for the histogram , it displays us there are data present in 5500 to 7900,it helps us to understand or to view the data set in a better way.

# %%
mat.scatter(insta['Number_of_Followers'],insta['Number_of_Followings'],color='y')
mat.show()

# %% [markdown]
# #### In histogram we have taken two variables''Number of Followers'' and ''Number of Followings'', there is outlier extreme high value which is placed in 7900 in yaxis,the maximum value of data in the dataset is occured between the values of (0 to 4000) in Y axis and (0 to 2000) in X axis but there are small amount of data is present across the histogram.

# %%
sea.distplot(insta['Number of Posts'],color='r')
mat.show()
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### by using the rug it has highlighted the data which has values in Number of posts in the bottom of the values, from the values around 50 to 2000 the variable has more data in the dataset but it reaches its peak value around 50 to 100 value in this we have take data which is less 8000 in the number of posts variable.

# %%
sea.distplot(insta['Number_of_Followers'][:500],rug=True,color='r')
mat.show()
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### by using the rug it has highlighted the data which has values in price variable in the bottom of the values, from the values around 1 to 2000 the variable has more data in the dataset but it reaches its peak value around 1 to 100 value in this we have take data which is less than 12000 in the followers variable.

# %%
sea.distplot(insta['Number_of_Followings'],hist=False,color='r')
mat.show()
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### by using the hist function and giving false it show us only the line in the data and it does not displays the bar in the plots

# %%
sea.boxplot(insta['Number_of_Followings'])
mat.title('Number_of_Followings')
mat.show()
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### There are outliers high extreme value in the dataset in which plotted in 8000 followings of instagram but the boxplot which has more data is plotted in the values of 500 to 2900 followings of instagram but there are also outliers from 6100 to 8000 foolowings in instagram which is plotted in the dataset.

# %%
sea.boxplot(y=insta['Number_of_Followings'])
mat.title('Number_of_Followings')
mat.show()

# %% [markdown]
# #### we have displayed the dataset in the vertical view in order to have clear view of understanding about dataset.

# %%
sea.jointplot(x='Number_of_Followers',y='Number_of_Followings',data=insta)
mat.show()

# %%
sea.jointplot('Number_of_Followers','Number_of_Followings',insta,kind='reg',color='r')
mat.show()
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### we have created jointplot for two variables "Number of Followers" and "Number of Followings" the followers from 0 to 2000 are having followings from 0 to 3000

# %%
insta=insta[(insta.Number_of_Followers<500)&(insta.Number_of_Followings<1000)]
sea.jointplot(x='Number_of_Followers',y='Number_of_Followings',data=insta,kind='hex',color='g')
mat.show()
